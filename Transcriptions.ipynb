# %% [markdown]
# <a href="https://colab.research.google.com/github/sjtempgit/audio_trascribe/blob/main/Transcriptions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-9mv_nvxo
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-9mv_nvxo
#   Resolved https://github.com/openai/whisper.git to commit 517a43ecd132a2089d85f4ebc044728a71d49f6e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 38.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # New Section

# %%
# !whisper "01_ An Introduction.mp3"
# Out:
# 100%|█████████████████████████████████████| 1.51G/1.51G [00:20<00:00, 80.1MiB/s]
# ...

# %%
# !whisper "14_Constant rememberance.mp3" -o "14_Constant rememberance"
# Out:
# /usr/local/lib/python3.11/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# ...

# %% [markdown]
# # New Section

# %%
# !whisper "28_Love Him Who Loves All.mp3" -o "28_Love Him Who Loves All"
# Out:
# /usr/local/lib/python3.11/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# ...

# %%
# !whisper -h
# Out:
# usage: whisper [-h] [--model MODEL] [--model_dir MODEL_DIR] [--device DEVICE]
#                [--output_dir OUTPUT_DIR] [--output_format {txt,vtt,srt,tsv,json,all}]
#                [--verbose VERBOSE] [--task {transcribe,translate}]
# ...

# %%
# !whisper "02_Mind Can Know Mind.mp3"	      -o "02_Mind Can Know Mind"
# !whisper "03_Spiritual Essence.mp3"	      -o "03_Spiritual Essence"
# !whisper "04_Spiritual Experience.mp3"	      -o "04_Spiritual Experience"
# !whisper "05_Living Master.mp3"	      -o "05_Living Master"
# !whisper "06_The Understanding Comes.mp3"	      -o "06_The Understanding Comes"
# !whisper "07_IlluminedByDivineGrace.mp3"	      -o "07_IlluminedByDivineGrace"
# !whisper "08_happiest man who is happy....mp3"	      -o "08_happiest man who is happy..."
# !whisper "09_LionHeartedMen.mp3"	      -o "09_LionHeartedMen"
# !whisper "10_TrulySpeaking.mp3"	      -o "10_TrulySpeaking"
# !whisper "11_dependency.mp3"	      -o "11_dependency"
# !whisper "12_prayer.mp3"	      -o "12_prayer"
# !whisper "13_Colorlessness.mp3"	      -o "13_Colorlessness"
# !whisper "14_Constant rememberance.mp3"	      -o "14_Constant rememberance"
# !whisper "15_Sincerity.mp3"	      -o "15_Sincerity"
# !whisper "16_Every one endeavours.mp3"	      -o "16_Every one endeavours"
# !whisper "17_Company of Divine.mp3"	      -o "17_Company of Divine"
# !whisper "18_Ganga Jamuni.mp3"	      -o "18_Ganga Jamuni"
# !whisper "19_TheUnknown.mp3"	      -o "19_TheUnknown"
# !whisper "20-Morality.mp3"	      -o "20-Morality"
# !whisper "21_Santhusti.mp3"	      -o "21_Santhusti"
# !whisper "22_Absolute.mp3"	      -o "22_Absolute"
# !whisper "23_Faith in true sense.mp3"	      -o "23_Faith in true sense"
# !whisper "24_Oozing canopy.mp3"	      -o "24_Oozing canopy"
# !whisper "25_Purity.mp3"	      -o "25_Purity"
# !whisper "26_We must never be disappointed for divine grace.mp3”	      -o "26_We must never be disappointed for divine grace"
# !whisper "27_Reality.mp3"	      -o "27_Reality"
# !whisper "28_Love Him Who Loves All.mp3"	      -o "28_Love Him Who Loves All"
# !whisper "29_Restoring Our Balance.mp3"	      -o "29_Restoring Our Balance"
# !whisper "30_New Era.mp3"	      -o "30_New Era"
# !whisper "31_Humility.mp3"	      -o "31_Humility"
# !whisper "32_New Era and Our Responsibility.mp3"	      -o "32_New Era and Our Responsibility"
# !whisper "33_MuradMalamita.mp3"	      -o "33_MuradMalamita"
# !whisper "BP101SriRamchandraConsciousness.mp3"	      -o "BP101SriRamchandraConsciousness"
# !whisper "BP114Surrender.mp3"	      -o "BP114Surrender"
# !whisper "BP124_Solution to the problem of life.mp3"	      -o "BP124_Solution to the problem of life"
# !whisper "BP201BhagwanSriKrishna.mp3"	      -o "BP201BhagwanSriKrishna"
# !whisper "BP202_Meditation Methods practices.mp3"	      -o "BP202_Meditation Methods practices"
# !whisper "BP203Exposotion_on_Gita.mp3"	      -o "BP203Exposotion_on_Gita"
# !whisper "BP304Cooperation is the life of comming events.mp3”	      -o "BP304Cooperation is the life of comming events"
# !whisper "BP312PathofPain.mp3"	      -o "BP312PathofPain"
# !whisper "BP317This and that have gone now.mp3"	      -o "BP317This and that have gone now"
# !whisper "BP319When out of Reality we become satan.mp3	     -o "BP319When out of Reality we become satan.mp3
# !whisper "BP405_MeditationIsNotEnough.mp3"	      -o "BP405_MeditationIsNotEnough"
# !whisper "BP409_RevLalajiMaharaj_the advent.mp3"	      -o "BP409_RevLalajiMaharaj_the advent"
# !whisper "BP410_ImperienceOfVoid.mp3"	      -o "BP410_ImperienceOfVoid"
# !whisper "BP411_Freedom-Liberation.mp3"	      -o "BP411_Freedom-Liberation"
# !whisper "BP412 Love is the Inner Awakening to Reality.mp3”	      -o "BP412 Love is the Inner Awakening to Reality"
# !whisper "BP413_PlayDivine.mp3"	      -o "BP413_PlayDivine"
# !whisper "BP414_Moulding_Preceptors_Business.mp3"	      -o "BP414_Moulding_Preceptors_Business"
# !whisper "BP415_Divinity_play_.mp3"	      -o "BP415_Divinity_play_"
# !whisper "BP416_service-serf.mp3"	      -o "BP416_service-serf"
# !whisper "BP418_Surrender is the keyword.mp3"	      -o "BP418_Surrender is the keyword"
# !whisper "BP419_Rings of Egoism.mp3"	      -o "BP419_Rings of Egoism"
# !whisper "BP420_Proper Motivation.mp3"	      -o "BP420_Proper Motivation"
# !whisper "BP421Path to Liberation.mp3"	      -o "BP421Path to Liberation"
# !whisper "BP501_New Era of Spirituality.mp3"	      -o "BP501_New Era of Spirituality"
# !whisper "BP502_On Repentance_Pardon.mp3"	      -o "BP502_On Repentance_Pardon"
# !whisper "BP503_Some thoughts on Samadarsi.mp3"	      -o "BP503_Some thoughts on Samadarsi"
# !whisper "BP504_The Virtue of truth.mp3"	      -o "BP504_The Virtue of truth"
# !whisper "BP505_Rev Babuji Innovate path.mp3"	      -o "BP505_Rev Babuji Innovate path"
# !whisper "BP506_SriKrishna Thru SriRamchandra.mp3"	      -o "BP506_SriKrishna Thru SriRamchandra"
# !whisper "BP507_On IMP-EventHorizon.mp3"	      -o "BP507_On IMP-EventHorizon"
# !whisper "BP508_Our Spiritual Order.mp3"	      -o "BP508_Our Spiritual Order"
# !whisper "BP509_PhilosophyOfNaturalPath.mp3"	      -o "BP509_PhilosophyOfNaturalPath"
# !whisper "BP510_Attempt infinite with finite.mp3"	      -o "BP510_Attempt infinite with finite"
# !whisper "BP511_Demolition of the past.mp3"	      -o "BP511_Demolition of the past"
# !whisper "BP512_Remembrance of everything.mp3"	      -o "BP512_Remembrance of everything"
# !whisper "BP513_It is the Divine command.mp3"	      -o "BP513_It is the Divine command"
# !whisper "BP514_They take milk and also pickle.mp3"	      -o "BP514_They take milk and also pickle"
# !whisper "BP515_We are and we are not.mp3"	      -o "BP515_We are and we are not"
# !whisper "BP516_No doubt world will be paradise.mp3"	      -o "BP516_No doubt world will be paradise"
# !whisper "BP517_ Dogmatic and Godmatic.mp3"	      -o "BP517_ Dogmatic and Godmatic"
# Out:
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# /bin/bash: line 1: whisper: command not found
# ...

# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-vo5ti0rv
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-vo5ti0rv
#   Resolved https://github.com/openai/whisper.git to commit 517a43ecd132a2089d85f4ebc044728a71d49f6e
#   Installing build dependencies ... done
# ERROR: Operation cancelled by user
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# ...

# %%
# !whisper "02_Mind Can Know Mind.mp3"  -o "02_Mind Can Know Mind"
# Out:
# /usr/local/lib/python3.11/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# ...

# %%
# !whisper "/02_Mind Can Know Mind.mp3" -o "02_Mind Can Know Mind.mp3"
# Out:
# /usr/local/lib/python3.11/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# ...

# %%
# !whisper "/03_Spiritual Essence.mp3"                                  -o "03_Spiritual Essence"
# !whisper "/04_Spiritual Experience.mp3"                               -o "04_Spiritual Experience"
# !whisper "/05_Living Master.mp3"                                      -o "05_Living Master"
# !whisper "/06_The Understanding Comes.mp3"                            -o "06_The Understanding Comes"
# !whisper "/07_IlluminedByDivineGrace.mp3"                             -o "07_IlluminedByDivineGrace"
# !whisper "/08_happiest man who is happy....mp3"                       -o "08_happiest man who is happy..."
# !whisper "/09_LionHeartedMen.mp3"                                     -o "09_LionHeartedMen"
# !whisper "/10_TrulySpeaking.mp3"                                      -o "10_TrulySpeaking"
# !whisper "/11_dependency.mp3"                                         -o "11_dependency"
# !whisper "/12_prayer.mp3"                                             -o "12_prayer"
# !whisper "/13_Colorlessness.mp3"                                      -o "13_Colorlessness"
# !whisper "/14_Constant rememberance.mp3"                              -o "14_Constant rememberance"
# !whisper "/15_Sincerity.mp3"                                          -o "15_Sincerity"
# !whisper "/16_Every one endeavours.mp3"                               -o "16_Every one endeavours"
# !whisper "/17_Company of Divine.mp3"                                  -o "17_Company of Divine"
# !whisper "/18_Ganga Jamuni.mp3"                                       -o "18_Ganga Jamuni"
# !whisper "/19_TheUnknown.mp3"                                         -o "19_TheUnknown"
# !whisper "/20-Morality.mp3"                                           -o "20-Morality"
# !whisper "/21_Santhusti.mp3"                                          -o "21_Santhusti"
# !whisper "/22_Absolute.mp3"                                           -o "22_Absolute"
# !whisper "/23_Faith in true sense.mp3"                                -o "23_Faith in true sense"
# !whisper "/24_Oozing canopy.mp3"                                      -o "24_Oozing canopy"
# !whisper "/25_Purity.mp3"                                             -o "25_Purity"
# !whisper "/26_We must never be disappointed for divine grace.mp3"     -o "26_We must never be disappointed for divine grace"
# !whisper "/27_Reality.mp3"                                            -o "27_Reality"
# !whisper "/28_Love Him Who Loves All.mp3"                             -o "28_Love Him Who Loves All"
# !whisper "/29_Restoring Our Balance.mp3"                              -o "29_Restoring Our Balance"
# !whisper "/30_New Era.mp3"                                            -o "30_New Era"
# !whisper "/31_Humility.mp3"                                           -o "31_Humility"
# !whisper "/32_New Era and Our Responsibility.mp3"                     -o "32_New Era and Our Responsibility"
# !whisper "/33_MuradMalamita.mp3"                                      -o "33_MuradMalamita"
# !whisper "/BP101SriRamchandraConsciousness.mp3"                       -o "BP101SriRamchandraConsciousness"
# !whisper "/BP114Surrender.mp3"                                        -o "BP114Surrender"
# !whisper "/BP124_Solution to the problem of life.mp3"                 -o "BP124_Solution to the problem of life"
# !whisper "/BP201BhagwanSriKrishna.mp3"                                -o "BP201BhagwanSriKrishna"
# !whisper "/BP202_Meditation Methods practices.mp3"                    -o "BP202_Meditation Methods practices"
# !whisper "/BP203Exposotion_on_Gita.mp3"                               -o "BP203Exposotion_on_Gita"
# !whisper "/BP304Cooperation is the life of comming events.mp3"        -o "BP304Cooperation is the life of comming events"
# !whisper "/BP312PathofPain.mp3"                                       -o "BP312PathofPain"
# !whisper "/BP317This and that have gone now.mp3"                      -o "BP317This and that have gone now"
# !whisper "/BP319When out of Reality we become satan.mp3"              -o "BP319When out of Reality we become satan.mp3
# !whisper "/BP405_MeditationIsNotEnough.mp3"                           -o "BP405_MeditationIsNotEnough"
# !whisper "/BP409_RevLalajiMaharaj_the advent.mp3"                     -o "BP409_RevLalajiMaharaj_the advent"
# !whisper "/BP410_ImperienceOfVoid.mp3"                                -o "BP410_ImperienceOfVoid"
# !whisper "/BP411_Freedom-Liberation.mp3"                              -o "BP411_Freedom-Liberation"
# !whisper "/BP412 Love is the Inner Awakening to Reality.mp3"          -o "BP412 Love is the Inner Awakening to Reality"
# !whisper "/BP413_PlayDivine.mp3"                                      -o "BP413_PlayDivine"
# !whisper "/BP414_Moulding_Preceptors_Business.mp3"                    -o "BP414_Moulding_Preceptors_Business"
# !whisper "/BP415_Divinity_play_.mp3"                                  -o "BP415_Divinity_play_"
# !whisper "/BP416_service-serf.mp3"                                    -o "BP416_service-serf"
# !whisper "/BP418_Surrender is the keyword.mp3"                        -o "BP418_Surrender is the keyword"
# !whisper "/BP419_Rings of Egoism.mp3"                                 -o "BP419_Rings of Egoism"
# !whisper "/BP420_Proper Motivation.mp3"                               -o "BP420_Proper Motivation"
# !whisper "/BP421Path to Liberation.mp3"                               -o "BP421Path to Liberation"
# !whisper "/BP501_New Era of Spirituality.mp3"                         -o "BP501_New Era of Spirituality"
# !whisper "/BP502_On Repentance_Pardon.mp3"                            -o "BP502_On Repentance_Pardon"
# !whisper "/BP503_Some thoughts on Samadarsi.mp3"                      -o "BP503_Some thoughts on Samadarsi"
# !whisper "/BP504_The Virtue of truth.mp3"                             -o "BP504_The Virtue of truth"
# !whisper "/BP505_Rev Babuji Innovate path.mp3"                        -o "BP505_Rev Babuji Innovate path"
# !whisper "/BP506_SriKrishna Thru SriRamchandra.mp3"                   -o "BP506_SriKrishna Thru SriRamchandra"
# !whisper "/BP507_On IMP-EventHorizon.mp3"                             -o "BP507_On IMP-EventHorizon"
# !whisper "/BP508_Our Spiritual Order.mp3"                             -o "BP508_Our Spiritual Order"
# !whisper "/BP509_PhilosophyOfNaturalPath.mp3"                         -o "BP509_PhilosophyOfNaturalPath"
# !whisper "/BP510_Attempt infinite with finite.mp3"                    -o "BP510_Attempt infinite with finite"
# !whisper "/BP511_Demolition of the past.mp3"                          -o "BP511_Demolition of the past"
# !whisper "/BP512_Remembrance of everything.mp3"                       -o "BP512_Remembrance of everything"
# !whisper "/BP513_It is the Divine command.mp3"                        -o "BP513_It is the Divine command"
# !whisper "/BP514_They take milk and also pickle.mp3"                  -o "BP514_They take milk and also pickle"
# !whisper "/BP515_We are and we are not.mp3"                           -o "BP515_We are and we are not"
# !whisper "/BP516_No doubt world will be paradise.mp3"                 -o "BP516_No doubt world will be paradise"
# !whisper "/BP517_ Dogmatic and Godmatic.mp3"                          -o "BP517_ Dogmatic and Godmatic"
# Out:
# Streaming output truncated to the last 5000 lines.
# [17:03.920 --> 17:04.420]  knows he
# [17:04.420 --> 17:05.060]  treated her
# [17:05.060 --> 17:05.600]  very well,
# [17:06.000 --> 17:06.520]  since it is
# [17:06.520 --> 17:07.060]  a time of
# [17:07.060 --> 17:07.520]  separation,
# [17:08.140 --> 17:08.760]  she will leave
# [17:08.760 --> 17:09.980]  him and go
# [17:09.980 --> 17:10.620]  on her own.
# [17:11.360 --> 17:11.720]  Then he
# [17:11.720 --> 17:12.100]  called his
# [17:12.100 --> 17:12.660]  second wife
# [17:12.660 --> 17:13.420]  to his
# [17:13.420 --> 17:14.560]  sickbed and
# [17:14.560 --> 17:15.160]  begged her to
# [17:15.160 --> 17:15.980]  follow him in
# [17:15.980 --> 17:16.240]  death.
# [17:16.720 --> 17:17.320]  She expressed
# [17:17.320 --> 17:18.000]  herself rather
# [17:18.000 --> 17:18.580]  coldly,
# [17:18.960 --> 17:19.820]  stating that
# [17:19.820 --> 17:20.220]  since your
# [17:20.220 --> 17:20.700]  first wife
# ...
